# %% [markdown]
# カルト本部一覧

# %%
import folium
import pandas as pd
import matplotlib.pyplot as plt
karuto= pd.read_csv('okaruto.csv')
m=folium.Map(location=[35.43057154571769,139.38236346549488], zoom_start=7)
for index, row in karuto.iterrows():
    latlon = [row['latitude'],row['longitude']]
    folium.Marker(latlon, 
                  popup='<div style="width:350px">'+'</div>', 
                  tooltip=row['name'],
                ).add_to(m)
m.save('map.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dbbdfa1ebef9790181c6834b430d3936 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dbbdfa1ebef9790181c6834b430d3936&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dbbdfa1ebef9790181c6834b430d3936 = L.map(
#                 &quot;map_dbbdfa1ebef9790181c6834b430d3936&quot;,
#                 {
#                     center: [35.43057154571769, 139.38236346549488],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4b39ebd5e15cd11c694b333689632ac3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4b39ebd5e15cd11c694b333689632ac3.addTo(map_dbbdfa1ebef9790181c6834b430d3936);
#
#
#             var marker_e4656a57207907d08f12a05a7148c4fa = L.marker(
#                 [35.43057154571769, 139.38236346549488],
#                 {}
#             ).addTo(map_dbbdfa1ebef9790181c6834b430d3936);
#
#
#         var popup_c9b692901c4917a61edbe2520af6cdf9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d5da964120a577a97f52685f6d1714f1 = $(`&lt;div id=&quot;html_d5da964120a577a97f52685f6d1714f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:350px&quot;&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_c9b692901c4917a61edbe2520af6cdf9.setContent(html_d5da964120a577a97f52685f6d1714f1);
#
#
#
#         marker_e4656a57207907d08f12a05a7148c4fa.bindPopup(popup_c9b692901c4917a61edbe2520af6cdf9)
#         ;
#
#
#
#
#             marker_e4656a57207907d08f12a05a7148c4fa.bindTooltip(
#                 `&lt;div&gt;
#                      エホバの証人日本支部
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_890486d8f8301fb18bd7878a6676c58e = L.marker(
#                 [35.68310472007252, 139.71928546151167],
#                 {}
#             ).addTo(map_dbbdfa1ebef9790181c6834b430d3936);
#
#
#         var popup_1b9c738c9b74e94b23b2ceb4fb8b3e4c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3ccd1adcbe41c8c658d15559cbda22dc = $(`&lt;div id=&quot;html_3ccd1adcbe41c8c658d15559cbda22dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:350px&quot;&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_1b9c738c9b74e94b23b2ceb4fb8b3e4c.setContent(html_3ccd1adcbe41c8c658d15559cbda22dc);
#
#
#
#         marker_890486d8f8301fb18bd7878a6676c58e.bindPopup(popup_1b9c738c9b74e94b23b2ceb4fb8b3e4c)
#         ;
#
#
#
#
#             marker_890486d8f8301fb18bd7878a6676c58e.bindTooltip(
#                 `&lt;div&gt;
#                      創価学会本部
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_29bf449f54928e7a8d35dda2808091c6 = L.marker(
#                 [35.62924438280277, 139.72701274846872],
#                 {}
#             ).addTo(map_dbbdfa1ebef9790181c6834b430d3936);
#
#
#         var popup_139cd58be898f85e616b1047c0d7bd6c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f1fb21a97d35ea555873bbedf60a0d45 = $(`&lt;div id=&quot;html_f1fb21a97d35ea555873bbedf60a0d45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:350px&quot;&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_139cd58be898f85e616b1047c0d7bd6c.setContent(html_f1fb21a97d35ea555873bbedf60a0d45);
#
#
#
#         marker_29bf449f54928e7a8d35dda2808091c6.bindPopup(popup_139cd58be898f85e616b1047c0d7bd6c)
#         ;
#
#
#
#
#             marker_29bf449f54928e7a8d35dda2808091c6.bindTooltip(
#                 `&lt;div&gt;
#                      幸福の科学総合本部
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f2a7d3fcd903b10283a78804825955db = L.marker(
#                 [35.67069597274692, 139.59869595125608],
#                 {}
#             ).addTo(map_dbbdfa1ebef9790181c6834b430d3936);
#
#
#         var popup_b9b67b0240aebe8c074defbc2f0d6a2b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f4b4c343a6a38c80fa1493d1571b66ee = $(`&lt;div id=&quot;html_f4b4c343a6a38c80fa1493d1571b66ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:350px&quot;&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_b9b67b0240aebe8c074defbc2f0d6a2b.setContent(html_f4b4c343a6a38c80fa1493d1571b66ee);
#
#
#
#         marker_f2a7d3fcd903b10283a78804825955db.bindPopup(popup_b9b67b0240aebe8c074defbc2f0d6a2b)
#         ;
#
#
#
#
#             marker_f2a7d3fcd903b10283a78804825955db.bin
